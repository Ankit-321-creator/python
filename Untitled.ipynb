# %%
print("welcome to ankit jakhar")
# Out:
# welcome to ankit jakhar

# %%
#addition
num1 =float(input("enter the first number"))
num2 =float(input("enter the second number"))
sum_result =num1+num2
print(f"sum: {sum_result}")
# Out:
# enter the first number 23.4
# enter the second number 34.4
# sum: 57.8

# %%
#division
num1 =float(input("enter the first number :"))
num2 =float(input("enter the second number :"))
if num2  ==0:
    print("error : the result is not allowed")
else:
    div_result =num1/num2
    print(f"division : {num1}/{num2} ={div_result}")
# Out:
# enter the first number : 34.5
# enter the second number : 3
# division : 34.5/3.0 =11.5

# %%
#input the bas and height from the input of traingle
base =int(input("enter the base "))
height=int(input("enter the height :"))
area = 0.5 *base * height
print(f"the area of result : {area}")
# Out:
# enter the base  8
# enter the height : 46
# the area of result : 184.0

# %% [markdown]
# # swap number

# %%
a =5
b=6
print(f" a = {a} ,b ={b}")
temp =a
a =b
temp =b
print(f" a= {temp} , b ={a}")
# Out:
#  a = 5 ,b =6
#  a= 6 , b =6

# %% [markdown]
# # generate the ramdom number

# %%
import random
print(f" random number :{random.randint(1,100)}")
# Out:
#  random number :27

# %% [markdown]
# # conersion of kilometers to miles

# %%
# conversion fectors : i kilometers =0.6213
kilometers =int(input("enter the distance in kilometers :"))
conversion_fector =0.621
miles =kilometers * conversion_fector
print(F"{kilometers } kilometers is equal to {miles} miles")
# Out:
# enter the distance in kilometers : 100
# 100 kilometers is equal to 62.1 miles

# %% [markdown]
# # celsius to fahrenheit

# %%
celsius =float(input("enter temprature in celsius:"))
# ferehenit =celsius*9/5+32 ferehenit
forenight =celsius*9/5 +32
print(f"{}")
